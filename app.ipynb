# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://brasil.io/dataset/covid19/caso?format=csv')
df
# Out:
#             date state               city place_type  confirmed  deaths  \
# 0     2020-04-06    AC         Acrelândia       city          9     0.0
# 1     2020-04-06    AC  Plácido de Castro       city          1     0.0
# 2     2020-04-06    AC         Porto Acre       city          1     0.0
# 3     2020-04-06    AC         Rio Branco       city         39     1.0
# 4     2020-04-06    AC                NaN      state         50     1.0
# ...          ...   ...                ...        ...        ...     ...
# 6914  2020-02-28    SP                NaN      state          2     NaN
# 6915  2020-02-27    SP          São Paulo       city          1     NaN
# 6916  2020-02-27    SP                NaN      state          1     NaN
# 6917  2020-02-26    SP          São Paulo       city          1     NaN
# 6918  2020-02-26    SP                NaN      state          1     NaN
#
#       is_last  estimated_population_2019  city_ibge_code  \
# 0        True                    15256.0       1200013.0
# 1        True                    19761.0       1200385.0
# 2        True                    18504.0       1200807.0
# 3        True                   407319.0       1200401.0
# 4        True                   881935.0            12.0
# ...       ...                        ...             ...
# 6914    False                 45919049.0            35.0
# 6915    False                 12252023.0       3550308.0
# 6916    False                 45919049.0            35.0
# 6917    False                 12252023.0       3550308.0
# 6918    False                 45919049.0            35.0
#
#       confirmed_per_100k_inhabitants  death_rate
# 0                           58.99318         NaN
# 1                            5.06047         NaN
# 2                            5.40424         NaN
# 3                            9.57481      0.0256
# 4                            5.66935      0.0200
# ...                              ...         ...
# 6914                         0.00436         NaN
# 6915                         0.00816         NaN
# 6916                         0.00218         NaN
# 6917                         0.00816         NaN
# 6918                         0.00218         NaN
#
# [6919 rows x 11 columns]

# %%
# validação dos valores
df_estado = df.loc[df['place_type'] == 'state']
df_estado = df_estado.loc[df['state'] == 'RS']

df_estado_confirmed = df_estado.groupby('date').sum()['confirmed'].reset_index() ## 410

df_estado_deaths = df_estado.groupby('date').sum()['deaths'].reset_index() ## 6

print("confimados RS:", max(df_estado_confirmed['confirmed']))
print("mortes RS:", max(df_estado_deaths['deaths']))


print("\n")


df_estado = df.loc[df['place_type'] == 'city']
df_estado = df_estado.loc[df['state'] == 'RS']

df_estado_confirmed = df_estado.groupby('date').sum()['confirmed'].reset_index() ## 410

df_estado_deaths = df_estado.groupby('date').sum()['deaths'].reset_index() ## 6

print("total confimados por cidade:", max(df_estado_confirmed['confirmed']))
print("total mortes por cidade:", max(df_estado_deaths['deaths']))
# Out:
# confimados RS: 501
# mortes RS: 8.0
#
#
# total confimados por cidade: 501
# total mortes por cidade: 8.0

# %% [markdown]
# ## Análise
#
# <p> As linhas cujo campo place_type tem o valor de 'state' recebem os valores agrupados pelo estado, farei minha análise em cima dos dados agrupados por cidade</p>
#
# <p> Analisarei algumas cidades da região metropolitana de Porto Alegre e do vale dos sinos </p>

# %%
state = 'RS'
city = 'Taquari'

df_confirmed = df_cities.loc[ df_cities['state'] == state ]
df_confirmed = df_confirmed.loc[ df_cities['city'] == city ]
df_confirmed = df_confirmed.sort_values(by='date')

df_confirmed[['date', 'confirmed']]
# Out:
#             date  confirmed
# 3835  2020-03-30          1
# 3414  2020-03-31          1
# 2964  2020-04-01          1
# 2464  2020-04-02          1
# 1923  2020-04-03          1
# 1326  2020-04-04          1
# 727   2020-04-05          1
# 263   2020-04-06          1

# %%
state = 'RS'
city = 'Taquari'

df_deaths = df_cities.loc[ df_cities['state'] == state ]
df_deaths = df_deaths.loc[ df_cities['city'] == city ]
df_deaths = df_deaths.sort_values(by='date')

df_deaths[['date', 'deaths']]
# Out:
#             date  deaths
# 3835  2020-03-30     0.0
# 3414  2020-03-31     0.0
# 2964  2020-04-01     0.0
# 2464  2020-04-02     0.0
# 1923  2020-04-03     0.0
# 1326  2020-04-04     0.0
# 727   2020-04-05     0.0
# 263   2020-04-06     0.0

# %%
plt.figure(figsize=(25, 10))
plt.plot(df_confirmed['date'], df_confirmed['confirmed'])
plt.show()

plt.figure(figsize=(25, 10))
plt.plot(df_deaths['date'], df_deaths['deaths'])
plt.show()

# %%
def plot(a, b, situation, city):
    plt.figure(figsize=(25, 10))
    plt.title('Gráfico de {} para {}'.format(situation, city))
    plt.plot(a, b)
    plt.show()

def analisar_cidade_situacao(city: str, situacao: str):
    """
        Análise situação por cidade
    """

    state = 'RS'

    df_cities = df.loc[ df['state'] == state ]
    df_cities = df_cities.loc[ df_cities['city'] == city ]

    df_situation = df_cities.sort_values(by='date')
    # df_situation = df_cities.groupby('date').sum()[situacao].reset_index()
    df_situation = df_situation[['date', situacao]]
        
    plot(df_situation['date'], df_situation[situacao], situacao, city)

# %%
analisar_cidade_situacao("Novo Hamburgo", 'confirmed')
analisar_cidade_situacao("Novo Hamburgo", 'deaths')

# %%
def get_dates():
    return df.date.sort_values().unique()

def comparar_cidades_situacao(cities: list, situation: str):
    """
        Análise de comparação por cidade e situação
    """

    df_compair = pd.DataFrame({'date': get_dates()})

    for city in cities:
        df_cities = df.loc[ df['city'] == city ]

        df_situation = df_cities[['date', situation]]
        df_situation = df_situation.sort_values(by='date')
        df_situation.columns = ['date', city]
        df_compair = pd.merge(df_compair, df_situation, on='date', how='left') 
        
    return df_compair

# %%
qwe = comparar_cidades_situacao(['Novo Hamburgo', 'Campo Bom', 'Porto Alegre'], 'confirmed')
qwe
# Out:
#           date  Novo Hamburgo  Campo Bom  Porto Alegre
# 0   2020-02-26            NaN        NaN           NaN
# 1   2020-02-27            NaN        NaN           NaN
# 2   2020-02-28            NaN        NaN           NaN
# 3   2020-02-29            NaN        NaN           NaN
# 4   2020-03-01            NaN        NaN           NaN
# 5   2020-03-02            NaN        NaN           NaN
# 6   2020-03-03            NaN        NaN           NaN
# 7   2020-03-04            NaN        NaN           NaN
# 8   2020-03-05            NaN        NaN           NaN
# 9   2020-03-06            NaN        NaN           NaN
# 10  2020-03-07            NaN        NaN           NaN
# 11  2020-03-08            NaN        NaN           NaN
# 12  2020-03-09            NaN        NaN           NaN
# 13  2020-03-10            NaN        1.0           NaN
# 14  2020-03-11            NaN        1.0           1.0
# 15  2020-03-12            NaN        1.0           2.0
# 16  2020-03-13            NaN        1.0           2.0
# 17  2020-03-14            NaN        NaN           NaN
# 18  2020-03-15            NaN        NaN           NaN
# 19  2020-03-16            NaN        1.0           6.0
# 20  2020-03-17            NaN        NaN           NaN
# 21  2020-03-18            NaN        1.0          15.0
# 22  2020-03-19            NaN        2.0          20.0
# 23  2020-03-20            NaN        2.0          25.0
# 24  2020-03-21            NaN        2.0          35.0
# 25  2020-03-22            NaN        2.0          38.0
# 26  2020-03-23            NaN        2.0          41.0
# 27  2020-03-24            NaN        2.0          47.0
# 28  2020-03-25            NaN        2.0          87.0
# 29  2020-03-26            NaN        2.0         103.0
# 30  2020-03-27            NaN        2.0         107.0
# 31  2020-03-28            NaN        2.0         107.0
# 32  2020-03-29            1.0        2.0         135.0
# 33  2020-03-30            2.0        2.0         143.0
# 34  2020-03-31            2.0        2.0         190.0
# 35  2020-04-01            3.0        2.0         190.0
# 36  2020-04-02            4.0        2.0         232.0
# 37  2020-04-03           14.0        3.0         233.0
# 38  2020-04-04           14.0        3.0         241.0
# 39  2020-04-05           19.0        3.0         254.0
# 40  2020-04-06           20.0        4.0         253.0

# %%
qwe.plot()

# %% [markdown]
# ## Comparação dos casos confirmados de algumas cidades do vale dos sinos

# %%
def plot(a, b, situation):
    plt.figure(figsize=(25, 10))
    plt.title('Gráfico de {}'.format(situation))
    plt.plot(a, b)
    plt.show()

df_vale_sinos = ['Sapiranga', 'Campo Bom', 'Dois Irmãos', 'Estância Velha', 'Novo Hamburgo', 'São Leopoldo', 'Sapucaia do Sul', 'Esteio', 'Canoas']

comp_vale_sinos = comparar_cidades_situacao(df_vale_sinos, 'confirmed')
plot(comp_vale_sinos['date'], comp_vale_sinos[df_vale_sinos], 'confirmed')

# %% [markdown]
# ## Apesar de saber que não se deve comparar as cidades cujo a população não seja equivalente, testarei a adição de Porto Alegre no próximo gráfico

# %%
def plot(a, b, situation):
    plt.figure(figsize=(25, 10))
    plt.title('Gráfico de {}'.format(situation))
    plt.plot(a, b)
    plt.show()

df_vale_sinos = ['Sapiranga', 'Campo Bom', 'Dois Irmãos', 'Estância Velha', 'Novo Hamburgo', 'São Leopoldo', 'Sapucaia do Sul', 'Esteio', 'Canoas', 'Porto Alegre']

comp_vale_sinos = comparar_cidades_situacao(df_vale_sinos, 'confirmed')
plot(comp_vale_sinos['date'], comp_vale_sinos[df_vale_sinos], 'confirmed')

# %%
df_vale_sinos = ['Canoas', 'Porto Alegre']

comp_vale_sinos = comparar_cidades_situacao(df_vale_sinos, 'deaths')
plot(comp_vale_sinos['date'], comp_vale_sinos[df_vale_sinos], 'óbitos')
